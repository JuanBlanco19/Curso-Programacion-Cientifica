# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanBlanco19/Curso-Programacion-Cientifica/blob/main/ejercicios/clase1_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# # Introduccion a la Programacion Cientifica
#
# ## Introduccion a python
#
# Mi primer programa con **python** para el curso de *programacion* cientifica
#
# - Ejercicio 1
# - Ejercicio 2
# - Ejercicio 3
#
# 1. Ejercicio 1
# 2. Ejercicio 2
# 3. Ejercicio 3
#
# Markdown: Es un lenguaje de marcado ligero que permite dar formato a textos usando símbolos sencillos en un archivo de texto plano
